# %% [markdown]
# # Artificial Neural Network

# %% [markdown]
# ### Importing the libraries

# %%
import numpy as np
import pandas as pd
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.9.2'

# %% [markdown]
# ## Part 1 - Data Preprocessing

# %% [markdown]
# ### Importing the dataset

# %%
df = pd.read_csv('/content/Urgent_Care_2 - Ucare_Zocdoc_California.csv')

# %%
import re

# put the special characters in a list
special_char = ['"', '*', '/', '(', ')', ':', '\n','[',']',"'", ',']

special_char_escaped = list(map(re.escape, special_char))

df['Email'] = df['Email'].replace(special_char_escaped, '', regex=True)

# %%
df
# Out:
#                               Name  \
# 0                      Joan Nguyen
# 1                    Michelle Zhou
# 2                        zara khan
# 3                       Dr. Justin
# 4                   grigoryanobgyn
# ..                             ...
# 337                    AngelsofENT
# 338  Louisianamassagetherapyclinic
# 339          mountainmassagedayspa
# 340                     troybraces
# 341                   dreamnurse19
#
#                                                Company  \
# 0                     ediatrician at Kaiser Permanente
# 1    The Children's Clinic, "Serving Children and T...
# 2                   Palo Alto Foundation Medical Group
# 3         Dr. Justin Simon, MD - Berkeley, CA - Zocdoc
# 4      Dr. Gregory Shifrin, OB/GYN (New York) - Zocdoc
# ..                                                 ...
# 337                              Ent horizon nj health
# 338      Tui na near me - Reformas Integrales Albacete
# ...

# %% [markdown]
# **Splitting Coloumn by ,**

# %%
First_name  = df['Email'].str.split(',', expand=True)
df['First_Name'] = First_name
df
# Out:
#                               Name  \
# 0                      Joan Nguyen
# 1                    Michelle Zhou
# 2                        zara khan
# 3                       Dr. Justin
# 4                   grigoryanobgyn
# ..                             ...
# 337                    AngelsofENT
# 338  Louisianamassagetherapyclinic
# 339          mountainmassagedayspa
# 340                     troybraces
# 341                   dreamnurse19
#
#                                                Company  \
# 0                     ediatrician at Kaiser Permanente
# 1    The Children's Clinic, "Serving Children and T...
# 2                   Palo Alto Foundation Medical Group
# 3         Dr. Justin Simon, MD - Berkeley, CA - Zocdoc
# 4      Dr. Gregory Shifrin, OB/GYN (New York) - Zocdoc
# ..                                                 ...
# 337                              Ent horizon nj health
# 338      Tui na near me - Reformas Integrales Albacete
# ...

# %% [markdown]
# **Replacement @ data with ""**

# %%
df["First_Name"] = df["First_Name"].str.replace("@gmail.com", "")
df["First_Name"] = df["First_Name"].str.replace("@aol.com", "")
df["First_Name"] = df["First_Name"].str.replace("@outlook.com", "")
df["First_Name"] = df["First_Name"].str.replace("@yahoo.com", "")
df["First_Name"] = df["First_Name"].str.replace(".", "")
df
# Out:
# <ipython-input-24-38259e341868>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df["First_Name"] = df["First_Name"].str.replace("@gmail.com", "")
# <ipython-input-24-38259e341868>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df["First_Name"] = df["First_Name"].str.replace("@aol.com", "")
# <ipython-input-24-38259e341868>:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   df["First_Name"] = df["First_Name"].str.replace("@outlook.com", "")
# <ipython-input-24-38259e341868>:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   df["First_Name"] = df["First_Name"].str.replace("@yahoo.com", "")
# ...

# %% [markdown]
# **Removal of Duplicate Rows**

# %%
clean_rows = df.drop_duplicates()
clean_rows.head()
# Out:
#              Name                                            Company  \
# 0     Joan Nguyen                   ediatrician at Kaiser Permanente
# 1   Michelle Zhou  The Children's Clinic, "Serving Children and T...
# 2       zara khan                 Palo Alto Foundation Medical Group
# 3      Dr. Justin       Dr. Justin Simon, MD - Berkeley, CA - Zocdoc
# 4  grigoryanobgyn    Dr. Gregory Shifrin, OB/GYN (New York) - Zocdoc
#
#                                                 Link  \
# 0                                     www.zocdoc.com
# 1         https://www.linkedin.com/in/michellezhou3/
# 2                                     www.zocdoc.com
# 3  https://www.zocdoc.com/doctor/justin-simon-md-...
# 4  https://www.zocdoc.com/practice/dr-gregory-shi...
#
#                                   Email                          First_Name
# 0     joanna.nguyen@sonichealthcare.com     joannanguyen@sonichealthcarecom
# 1  michelle.zhou@thechildrensclinic.org  michellezhou@thechildrensclinicorg
# ...

# %%
clean_rows.to_csv('/content/Ucare_ZOCDOC_California_Data.csv')
